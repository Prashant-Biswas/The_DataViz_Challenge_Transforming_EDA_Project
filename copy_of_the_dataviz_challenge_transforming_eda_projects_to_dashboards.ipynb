# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashant-Biswas/The_DataViz_Challenge_Transforming_EDA_Project/blob/main/copy_of_the_dataviz_challenge_transforming_eda_projects_to_dashboards.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **The DataViz Challenge -Transforming EDA Project**

# %% [markdown]
# **Dataset Selection:**
#
# For this EDA project, we have chosen the "Airbnb Listings Data" dataset from 2 major cities: Chicago and New Orleans. This dataset provides a comprehensive snapshot of various attributes related to Airbnb listings, such as property type, neighbourhood, pricing, availability, and more. The dataset is ideal for conducting an in-depth exploration of the local Airbnb market and deriving actionable insights.

# %% [markdown]
# **GitHub Link:-**
#
# https://github.com/Prashant-Biswas/The_DataViz_Challenge_Transforming_EDA_Projects/blob/main/Copy_of_The_DataViz_Challenge_Transforming_EDA_Projects_to_Dashboards.ipynb

# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
# Dataset loading
#chicago
chicago_df = pd.read_csv('/content/drive/MyDrive/The DataViz Challenge - Transforming EDA Projects to Dashboards/Chicago.csv', low_memory=False)
# new or
new_orleans_df = pd.read_csv('/content/drive/MyDrive/The DataViz Challenge - Transforming EDA Projects to Dashboards/New Orleans.csv', low_memory=False)

# %%
#dataset first look chicago
chicago_df.head()
# Out:
#         id                                           name  host_id  \
# 0   2384.0  Hyde Park - Walk to The University of Chicago     2613
# 1   7126.0            Tiny Studio Apartment 94 Walk Score    17928
# 2  10945.0                          The Biddle House (#1)    33004
# 3  12140.0                       Lincoln Park Guest House    46734
# 4  28749.0     Quirky Bucktown Loft w/ Parking NO PARTIES    27506
#
#          host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0          Rebecca                  NaN     Hyde Park  41.78790  -87.58780
# 1            Sarah                  NaN     West Town  41.90166  -87.68021
# 2      At Home Inn                  NaN  Lincoln Park  41.91196  -87.63981
# 3  Shay And Robert                  NaN  Lincoln Park  41.92357  -87.64947
# 4            Lauri                  NaN  Logan Square  41.92137  -87.67933
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room  125.0               3                242  08-06-2024
# 1  Entire home/apt  104.0               2                527  01-06-2024
# 2  Entire home/apt  188.0               4                 93  16-06-2024
# 3     Private room  339.0               2                 16  27-05-2024
# 4  Entire home/apt  214.0               2                210  18-06-2024
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               2.10                               1               328
# 1               2.89                               1               297
# 2               0.75                               5               196
# 3               0.15                               1               151
# 4               1.27                               1                13
#
#    number_of_reviews_ltm       license
# 0                     23  R17000015609
# 1                     32  R24000114046
# 2                     26       2209984
# 3                      1  R20000055258
# 4                     33  R24000113825

# %%
#dataset first look new orland
new_orleans_df.head()
# Out:
#                     id                                   name    host_id  \
# 0   970324090541593163                     Comfort in Bywater   56212513
# 1   768293169006662066                   Cozy and Comfortable  136665450
# 2  1069600842896440330       Tons of Space,10 Beds,3 1/2 Bath  556686789
# 3             23588926                     Superdome Lux Home   55472287
# 4             12111787  Historic Courtyard Cabana New Orleans   54478905
#
#   host_name  neighbourhood_group  neighbourhood   latitude  longitude  \
# 0    Amanda                  NaN     St. Claude  29.966211 -90.041057
# 1    Joshua                  NaN     St. Claude  29.972380 -90.042320
# 2       Joe                  NaN  Algiers Point  29.953003 -90.050669
# 3    Kamiah                  NaN   Central City  29.942904 -90.090524
# 4     Kevin                  NaN  Algiers Point  29.950940 -90.049440
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt   83.0              30                  3  2024-05-06
# 1     Private room  180.0              30                  0         NaN
# 2  Entire home/apt  638.0               1                  3  2024-07-06
# 3  Entire home/apt  350.0               3                  6  2024-05-06
# 4  Entire home/apt   90.0              30                 52  2024-02-18
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.41                               1                82
# 1                NaN                               1               365
# 2               0.45                               1               111
# 3               0.27                               1               159
# 4               1.05                               2                64
#
#    number_of_reviews_ltm                       license
# 0                      3                           NaN
# 1                      0                           NaN
# 2                      3    23rstr-02500, 23ostr-01343
# 3                      2  22-RSTR-06703, 22-OSTR-08948
# 4                      2   20-RSTR-2157, 20-OSTR-21576

# %%
# rows and columns count of chicago
chicago_df.shape
# Out:
# (7952, 18)

# %%
# rows and columns count of new orland
new_orleans_df.shape
# Out:
# (7118, 18)

# %%
# column name in chicago
chicago_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
# column  name in new orland
new_orleans_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
# data information
new_orleans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7118 entries, 0 to 7117
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7118 non-null   int64
#  1   name                            7118 non-null   object
#  2   host_id                         7118 non-null   int64
#  3   host_name                       7118 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   7118 non-null   object
#  6   latitude                        7118 non-null   float64
#  7   longitude                       7118 non-null   float64
#  8   room_type                       7118 non-null   object
#  9   price                           5969 non-null   float64
#  10  minimum_nights                  7118 non-null   int64
#  11  number_of_reviews               7118 non-null   int64
#  12  last_review                     5977 non-null   object
#  13  reviews_per_month               5977 non-null   float64
#  14  calculated_host_listings_count  7118 non-null   int64
#  15  availability_365                7118 non-null   int64
#  16  number_of_reviews_ltm           7118 non-null   int64
#  17  license                         5822 non-null   object
# dtypes: float64(5), int64(7), object(6)
# memory usage: 1001.1+ KB

# %%
chicago_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7952 entries, 0 to 7951
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7952 non-null   float64
#  1   name                            7952 non-null   object
#  2   host_id                         7952 non-null   int64
#  3   host_name                       7952 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   7952 non-null   object
#  6   latitude                        7952 non-null   float64
#  7   longitude                       7952 non-null   float64
#  8   room_type                       7952 non-null   object
#  9   price                           7598 non-null   float64
#  10  minimum_nights                  7952 non-null   int64
#  11  number_of_reviews               7952 non-null   int64
#  12  last_review                     6503 non-null   object
#  13  reviews_per_month               6503 non-null   float64
#  14  calculated_host_listings_count  7952 non-null   int64
#  15  availability_365                7952 non-null   int64
#  16  number_of_reviews_ltm           7952 non-null   int64
#  17  license                         6417 non-null   object
# dtypes: float64(6), int64(6), object(6)
# memory usage: 1.1+ MB

# %%
chicago_df.describe().transpose()
# Out:
#                                  count          mean           std  \
# id                              7952.0  5.183935e+17  4.644178e+17
# host_id                         7952.0  2.023162e+08  1.822818e+08
# neighbourhood_group                0.0           NaN           NaN
# latitude                        7952.0  4.189248e+01  6.286780e-02
# longitude                       7952.0 -8.766210e+01  4.351413e-02
# price                           7598.0  2.255154e+02  2.455700e+02
# minimum_nights                  7952.0  1.409469e+01  2.669632e+01
# number_of_reviews               7952.0  5.253961e+01  9.865684e+01
# reviews_per_month               6503.0  1.914822e+00  2.034722e+00
# calculated_host_listings_count  7952.0  4.778647e+01  1.376649e+02
# availability_365                7952.0  2.084234e+02  1.122613e+02
# number_of_reviews_ltm           7952.0  1.430458e+01  2.159227e+01
#
#                                         min           25%           50%  \
# id                              2384.000000  4.175638e+07  6.595725e+17
# host_id                         2153.000000  4.030995e+07  1.280827e+08
# neighbourhood_group                     NaN           NaN           NaN
# latitude                          41.646767  4.186351e+01  4.189622e+01
# longitude                        -87.846720 -8.768591e+01 -8.765775e+01
# price                             13.000000  1.000000e+02  1.660000e+02
# minimum_nights                     1.000000  2.000000e+00  2.000000e+00
# number_of_reviews                  0.000000  2.000000e+00  1.600000e+01
# reviews_per_month                  0.010000  6.000000e-01  1.580000e+00
# calculated_host_listings_count     1.000000  1.000000e+00  4.000000e+00
# availability_365                   0.000000  1.160000e+02  2.230000e+02
# number_of_reviews_ltm              0.000000  0.000000e+00  6.000000e+00
#
#                                          75%           max
# id                              9.510802e+17  1.183400e+18
# host_id                         3.798203e+08  5.841344e+08
# neighbourhood_group                      NaN           NaN
# latitude                        4.193620e+01  4.202220e+01
# longitude                      -8.763097e+01 -8.752842e+01
# price                           2.660000e+02  5.120000e+03
# minimum_nights                  3.200000e+01  3.650000e+02
# number_of_reviews               6.500000e+01  3.689000e+03
# reviews_per_month               2.770000e+00  5.409000e+01
# calculated_host_listings_count  1.600000e+01  5.490000e+02
# availability_365                3.120000e+02  3.650000e+02
# number_of_reviews_ltm           2.300000e+01  4.920000e+02

# %%
new_orleans_df.describe().transpose()
# Out:
#                                  count          mean           std  \
# id                              7118.0  4.452001e+17  4.755550e+17
# host_id                         7118.0  2.127531e+08  1.931316e+08
# neighbourhood_group                0.0           NaN           NaN
# latitude                        7118.0  2.995811e+01  2.439501e-02
# longitude                       7118.0 -9.007386e+01  3.174685e-02
# price                           5969.0  1.997318e+02  4.555123e+02
# minimum_nights                  7118.0  1.328224e+01  2.401481e+01
# number_of_reviews               7118.0  6.566030e+01  1.009643e+02
# reviews_per_month               5977.0  1.711282e+00  1.705075e+00
# calculated_host_listings_count  7118.0  1.329980e+01  2.097836e+01
# availability_365                7118.0  1.893405e+02  1.237797e+02
# number_of_reviews_ltm           7118.0  1.313880e+01  1.907167e+01
#
#                                         min           25%           50%  \
# id                              19091.00000  2.933738e+07  5.403724e+07
# host_id                           971.00000  4.253634e+07  1.350421e+08
# neighbourhood_group                     NaN           NaN           NaN
# latitude                           29.89768  2.994253e+01  2.995547e+01
# longitude                         -90.13646 -9.008933e+01 -9.007349e+01
# price                              10.00000  9.000000e+01  1.300000e+02
# minimum_nights                      1.00000  1.000000e+00  2.000000e+00
# number_of_reviews                   0.00000  3.000000e+00  2.600000e+01
# reviews_per_month                   0.01000  5.300000e-01  1.350000e+00
# calculated_host_listings_count      1.00000  1.000000e+00  3.000000e+00
# availability_365                    0.00000  8.400000e+01  1.860000e+02
# number_of_reviews_ltm               0.00000  0.000000e+00  5.000000e+00
#
#                                          75%           max
# id                              9.133064e+17  1.238854e+18
# host_id                         3.967380e+08  5.969558e+08
# neighbourhood_group                      NaN           NaN
# latitude                        2.996948e+01  3.016104e+01
# longitude                      -9.006416e+01 -8.973709e+01
# price                           2.110000e+02  2.800100e+04
# minimum_nights                  3.000000e+01  1.125000e+03
# number_of_reviews               8.900000e+01  1.935000e+03
# reviews_per_month               2.440000e+00  4.480000e+01
# calculated_host_listings_count  1.400000e+01  8.500000e+01
# availability_365                3.080000e+02  3.650000e+02
# number_of_reviews_ltm           2.100000e+01  3.950000e+02

# %%
# null values in chicago
chicago_df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group               7952
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                              354
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1449
# reviews_per_month                 1449
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1535
# dtype: int64

# %%
# null values in new orleans
new_orleans_df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group               7118
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                             1149
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1141
# reviews_per_month                 1141
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1296
# dtype: int64

# %%
import missingno as msno

# Visualize missing values of chicago using a heatmap
msno.heatmap(chicago_df)
# Out:
# <Axes: >

# %%
# Visualize missing values of new orleans using a heatmap
msno.heatmap(new_orleans_df)
# Out:
# <Axes: >

# %%
# finding unique values in chicago
chicago_df.nunique()
# Out:
# id                                7623
# name                              7474
# host_id                           3447
# host_name                         1974
# neighbourhood_group                  0
# neighbourhood                       77
# latitude                          6606
# longitude                         6450
# room_type                            4
# price                              789
# minimum_nights                      49
# number_of_reviews                  437
# last_review                        735
# reviews_per_month                  669
# calculated_host_listings_count      38
# availability_365                   366
# number_of_reviews_ltm              119
# license                           4109
# dtype: int64

# %%
# finding unique values in new orleans
new_orleans_df.nunique()
# Out:
# id                                7118
# name                              6888
# host_id                           3410
# host_name                         1798
# neighbourhood_group                  0
# neighbourhood                       69
# latitude                          5337
# longitude                         5479
# room_type                            4
# price                              621
# minimum_nights                      37
# number_of_reviews                  452
# last_review                        900
# reviews_per_month                  635
# calculated_host_listings_count      45
# availability_365                   366
# number_of_reviews_ltm              113
# license                           4099
# dtype: int64

# %%
concatenated_df = pd.concat([chicago_df, new_orleans_df], axis=0, ignore_index=True)

# %%
concatenated_df.shape
# Out:
# (15070, 18)

# %%
concatenated_df.head()
# Out:
#         id                                           name  host_id  \
# 0   2384.0  Hyde Park - Walk to The University of Chicago     2613
# 1   7126.0            Tiny Studio Apartment 94 Walk Score    17928
# 2  10945.0                          The Biddle House (#1)    33004
# 3  12140.0                       Lincoln Park Guest House    46734
# 4  28749.0     Quirky Bucktown Loft w/ Parking NO PARTIES    27506
#
#          host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0          Rebecca                  NaN     Hyde Park  41.78790  -87.58780
# 1            Sarah                  NaN     West Town  41.90166  -87.68021
# 2      At Home Inn                  NaN  Lincoln Park  41.91196  -87.63981
# 3  Shay And Robert                  NaN  Lincoln Park  41.92357  -87.64947
# 4            Lauri                  NaN  Logan Square  41.92137  -87.67933
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room  125.0               3                242  08-06-2024
# 1  Entire home/apt  104.0               2                527  01-06-2024
# 2  Entire home/apt  188.0               4                 93  16-06-2024
# 3     Private room  339.0               2                 16  27-05-2024
# 4  Entire home/apt  214.0               2                210  18-06-2024
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               2.10                               1               328
# 1               2.89                               1               297
# 2               0.75                               5               196
# 3               0.15                               1               151
# 4               1.27                               1                13
#
#    number_of_reviews_ltm       license
# 0                     23  R17000015609
# 1                     32  R24000114046
# 2                     26       2209984
# 3                      1  R20000055258
# 4                     33  R24000113825

# %%
concatenated_df.describe().transpose()
# Out:
#                                   count          mean           std  \
# id                              15070.0  4.838221e+17  4.711148e+17
# host_id                         15070.0  2.072458e+08  1.875509e+08
# neighbourhood_group                 0.0           NaN           NaN
# latitude                        15070.0  3.625553e+01  5.958435e+00
# longitude                       15070.0 -8.880124e+01  1.204683e+00
# price                           13567.0  2.141715e+02  3.538572e+02
# minimum_nights                  15070.0  1.371095e+01  2.546738e+01
# number_of_reviews               15070.0  5.873689e+01  9.996490e+01
# reviews_per_month               12480.0  1.817341e+00  1.886724e+00
# calculated_host_listings_count  15070.0  3.149741e+01  1.024886e+02
# availability_365                15070.0  1.994100e+02  1.182227e+02
# number_of_reviews_ltm           15070.0  1.375395e+01  2.044811e+01
#
#                                        min           25%           50%  \
# id                              2384.00000  3.557761e+07  5.928661e+17
# host_id                          971.00000  4.083220e+07  1.305021e+08
# neighbourhood_group                    NaN           NaN           NaN
# latitude                          29.89768  2.995852e+01  4.177182e+01
# longitude                        -90.13646 -9.007281e+01 -8.773603e+01
# price                             10.00000  9.500000e+01  1.500000e+02
# minimum_nights                     1.00000  1.000000e+00  2.000000e+00
# number_of_reviews                  0.00000  2.000000e+00  2.100000e+01
# reviews_per_month                  0.01000  5.600000e-01  1.460000e+00
# calculated_host_listings_count     1.00000  1.000000e+00  3.000000e+00
# availability_365                   0.00000  9.500000e+01  2.090000e+02
# number_of_reviews_ltm              0.00000  0.000000e+00  6.000000e+00
#
#                                          75%           max
# id                              9.398872e+17  1.238854e+18
# host_id                         3.919452e+08  5.969558e+08
# neighbourhood_group                      NaN           NaN
# latitude                        4.189852e+01  4.202220e+01
# longitude                      -8.765558e+01 -8.752842e+01
# price                           2.470000e+02  2.800100e+04
# minimum_nights                  3.000000e+01  1.125000e+03
# number_of_reviews               7.600000e+01  3.689000e+03
# reviews_per_month               2.620000e+00  5.409000e+01
# calculated_host_listings_count  1.500000e+01  5.490000e+02
# availability_365                3.100000e+02  3.650000e+02
# number_of_reviews_ltm           2.200000e+01  4.920000e+02

# %%
concatenated_df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group               15070
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              1503
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        2590
# reviews_per_month                  2590
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                            2831
# dtype: int64

# %%
concatenated_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
concatenated_df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group               15070
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              1503
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        2590
# reviews_per_month                  2590
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                            2831
# dtype: int64

# %%
concatenated_df.describe().transpose()
# Out:
#                                   count          mean           std  \
# id                              15070.0  4.838221e+17  4.711148e+17
# host_id                         15070.0  2.072458e+08  1.875509e+08
# neighbourhood_group                 0.0           NaN           NaN
# latitude                        15070.0  3.625553e+01  5.958435e+00
# longitude                       15070.0 -8.880124e+01  1.204683e+00
# price                           13567.0  2.141715e+02  3.538572e+02
# minimum_nights                  15070.0  1.371095e+01  2.546738e+01
# number_of_reviews               15070.0  5.873689e+01  9.996490e+01
# reviews_per_month               12480.0  1.817341e+00  1.886724e+00
# calculated_host_listings_count  15070.0  3.149741e+01  1.024886e+02
# availability_365                15070.0  1.994100e+02  1.182227e+02
# number_of_reviews_ltm           15070.0  1.375395e+01  2.044811e+01
#
#                                        min           25%           50%  \
# id                              2384.00000  3.557761e+07  5.928661e+17
# host_id                          971.00000  4.083220e+07  1.305021e+08
# neighbourhood_group                    NaN           NaN           NaN
# latitude                          29.89768  2.995852e+01  4.177182e+01
# longitude                        -90.13646 -9.007281e+01 -8.773603e+01
# price                             10.00000  9.500000e+01  1.500000e+02
# minimum_nights                     1.00000  1.000000e+00  2.000000e+00
# number_of_reviews                  0.00000  2.000000e+00  2.100000e+01
# reviews_per_month                  0.01000  5.600000e-01  1.460000e+00
# calculated_host_listings_count     1.00000  1.000000e+00  3.000000e+00
# availability_365                   0.00000  9.500000e+01  2.090000e+02
# number_of_reviews_ltm              0.00000  0.000000e+00  6.000000e+00
#
#                                          75%           max
# id                              9.398872e+17  1.238854e+18
# host_id                         3.919452e+08  5.969558e+08
# neighbourhood_group                      NaN           NaN
# latitude                        4.189852e+01  4.202220e+01
# longitude                      -8.765558e+01 -8.752842e+01
# price                           2.470000e+02  2.800100e+04
# minimum_nights                  3.000000e+01  1.125000e+03
# number_of_reviews               7.600000e+01  3.689000e+03
# reviews_per_month               2.620000e+00  5.409000e+01
# calculated_host_listings_count  1.500000e+01  5.490000e+02
# availability_365                3.100000e+02  3.650000e+02
# number_of_reviews_ltm           2.200000e+01  4.920000e+02

# %%
concatenated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15070 entries, 0 to 15069
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              15070 non-null  float64
#  1   name                            15070 non-null  object
#  2   host_id                         15070 non-null  int64
#  3   host_name                       15070 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   15070 non-null  object
#  6   latitude                        15070 non-null  float64
#  7   longitude                       15070 non-null  float64
#  8   room_type                       15070 non-null  object
#  9   price                           13567 non-null  float64
#  10  minimum_nights                  15070 non-null  int64
#  11  number_of_reviews               15070 non-null  int64
#  12  last_review                     12480 non-null  object
#  13  reviews_per_month               12480 non-null  float64
#  14  calculated_host_listings_count  15070 non-null  int64
#  15  availability_365                15070 non-null  int64
#  16  number_of_reviews_ltm           15070 non-null  int64
#  17  license                         12239 non-null  object
# dtypes: float64(6), int64(6), object(6)
# memory usage: 2.1+ MB

# %%
concatenated_df.to_csv('concatenated_file.csv', index=False)

# Download the CSV file to your local machine
from google.colab import files
files.download('/content/concatenated_file.csv')

# %%
concatenated_df["last_review"].unique()
# Out:
# array(['08-06-2024', '01-06-2024', '16-06-2024', ..., '2023-12-07',
#        '2023-11-22', '2023-03-09'], dtype=object)

# %%
concatenated_df['name'].str.split('.')
# Out:
# 0        [Hyde Park - Walk to The University of Chicago]
# 1                  [Tiny Studio Apartment 94 Walk Score]
# 2                                [The Biddle House (#1)]
# 3                             [Lincoln Park Guest House]
# 4           [Quirky Bucktown Loft w/ Parking NO PARTIES]
#                               ...
# 15065                 [French Quarter Entire guesthouse]
# 15066                              [Mid city hide away!]
# 15067       [Lakeview New Orleans 15Mins from downtown!]
# 15068    [Large Uptown Home near Oak St Shops & Trolley]
# 15069                                       [Hope House]
# Name: name, Length: 15070, dtype: object

# %% [markdown]
# **Conclusion:**
#
# Airbnb, a prominent online platform, enables individuals to reserve accommodations spanning a spectrum from beds and rooms to apartments and entire homes across global locales. This user-centric platform serves as a conduit for seamless property rentals, negating the need for intricate intermediaries or substantial capital outlays. Notably, users can secure lodgings at significantly competitive rates relative to traditional hotels. Distinctively, Airbnb extends its reach to regions where convectional hotel presence might be limited, offering an avenue for lodging acquisition in underserved locales. Moreover, the inclination towards immersive local experiences often steers individuals towards selecting accommodations embedded within native communities, fostering a distinctive preference for authenticity and cultural engagement.

# %% [markdown]
# **Thanks**
